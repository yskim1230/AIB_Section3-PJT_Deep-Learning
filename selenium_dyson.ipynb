# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from time import sleep
import requests
import re
import pandas as pd
import numpy as np
import os
import time
import warnings

warnings.filterwarnings('ignore')
# Mac에서 brew로 설치한 chromedriver의 경로
webdriver_path = '/usr/local/bin/chromedriver'

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
global url
url = 'https://search.shopping.naver.com/catalog/30242647618?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhnbmbl4%7Cci%3D561716a728d0988abfd7c97771d215090227d58a%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Dbe2a76fbcdf75a9f67fdf1a0cb1b41566709e6e0'
time.sleep(1)

wd.get(url)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[4]/a').click()
time.sleep(1)

#5점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[2]/a').click()
time.sleep(1)

#1페이지
page_xpath = '//*[@id="section_review"]/div[3]/a[1]'

from selenium.common.exceptions import NoSuchElementException

review_data = []

for j in range(1, 11):
    # 페이지 선택     
    page_xpath = '//*[@id="section_review"]/div[3]/a[{}]'.format(j)
    wd.find_element(By.XPATH, page_xpath).click()
    time.sleep(1)
    
    # 리뷰 가져오기 
    for i in range(20):
        review_xpath = '//*[@id="section_review"]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '5'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df5 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df5
# Out:
#     Grade                                             Review
# 0       5  스마트한 공기청정기! 역시 다이슨입니다.\n믿고쓰는 다이슨 , 청소기입문하여 미세먼...
# 1       5  배송도 빠르고 안전하게 무사히 도착했어요! 무엇보다 다이슨 공기청정기 덕분에 인테리...
# 2       5  일단 배송 빠르구요, 포장상태도 단단히 잘 되어서 왔어요.개인적으로 스티로폼 잔뜩 ...
# 3       5  배송 아주 빠름 !!\n\n신축 아파트 이사와서 베이크아웃도 제대로 못한터라 .. ...
# 4       5  크기가 생각대로 크긴한데 디자인이 깔쌈?해서 집 한가운데에 세워둬도 거슬리지않네요....
# ..    ...                                                ...
# 185     5   라이브방송보고 주문했는데 설치는 간단해요\n소음은 아직 거슬릴정도는 아니라 지켜보려고요
# 186     5  다이슨 좋아요\n이쁘고\n각 유해뮬질 앱으로 수치 모니터링 가능하고\n비람 방행조절...
# 187     5   믿을수 있는 상품이에요. 다이슨 하나 놨을뿐인데, 분위기가 확 달라지네요. 강추합니다.
# 188     5  디자인은 말할 것도 없고 성능도 만족합니다. 특히, 포름알데히드도 제거한다고 하니 ...
# 189     5   다이슨 이름하나보고 샀어요\n디자인 너무 이뻐요\n포름알데히드 잘 빨아들이는거 맞겠죠?
#
# [190 rows x 2 columns]

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
global url
url = 'https://search.shopping.naver.com/catalog/30242647618?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhnbmbl4%7Cci%3D561716a728d0988abfd7c97771d215090227d58a%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Dbe2a76fbcdf75a9f67fdf1a0cb1b41566709e6e0'
time.sleep(1)

wd.get(url)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[4]/a').click()
time.sleep(1)

#4점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[3]/a').click()
time.sleep(1)

#1페이지
page_xpath = '//*[@id="section_review"]/div[3]/a[1]'

from selenium.common.exceptions import NoSuchElementException

review_data = []

for j in range(1, 5):
    # 페이지 선택     
    page_xpath = '//*[@id="section_review"]/div[3]/a[{}]'.format(j)
    wd.find_element(By.XPATH, page_xpath).click()
    time.sleep(1)
    
    # 리뷰 가져오기 
    for i in range(20):
        review_xpath = '//*[@id="section_review"]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '4'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df4 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df4
# Out:
#    Grade                                             Review
# 0      4  리모델링 한지 2년정도 된집에 살고 있고 voc가 상당히 높아.. 처음부터 창문형 ...
# 1      4  꾀나 크네요.집 평수가 작아서\n5년된 작은 청정기 쓰다 이사가면 바꿔야지 하다가 ...
# 2      4  제품에 스크래치가 있어 교환예정이에요.\n새상품 샀는데 기분은 좋진 않네요. 크기도...
# 3      4  벼르던 다이슨 라방보고 주문했어요.\n색상도 고급지고 디자인도 맘에 들어요\n사이즈...
# 4      4  처음으로 공청기를 비싼거를 사봤네요.\n에어로타워를 살까 고민하다가 라방종료 3분전...
# ..   ...                                                ...
# 71     4                                         소음이 조금 큽니다
# 72     4  쿨 기능 사용시 10단을 하지 않으면 바람이 많이 약함.. 10단 사용시 소음이 있...
# 73     4  리모콘 자석이 그리 단단치 않아 떨어져\n벌써 청정기 윗부분에 스크래치가 났네요 ㅠ...
# 74     4  새로 산 옷징이 E0인데도 눈이 따꺼웠는데 이 청정기 틀은 뒤로는 견딜만 해졌어요 ...
# 75     4              새집 입주선물로 구매했어요.인테리어효과도있고 기능은 좋길 기대합니다
#
# [76 rows x 2 columns]

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
global url
url = 'https://search.shopping.naver.com/catalog/30242647618?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhnbmbl4%7Cci%3D561716a728d0988abfd7c97771d215090227d58a%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Dbe2a76fbcdf75a9f67fdf1a0cb1b41566709e6e0'
time.sleep(1)

wd.get(url)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[4]/a').click()
time.sleep(1)

#3점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[4]/a').click()
time.sleep(1)

#1페이지
page_xpath = '//*[@id="section_review"]/div[3]/a[1]'

from selenium.common.exceptions import NoSuchElementException

review_data = []

for j in range(1, 2):
    # 페이지 선택     
    page_xpath = '//*[@id="section_review"]/div[3]/a[{}]'.format(j)
    wd.find_element(By.XPATH, page_xpath).click()
    time.sleep(1)
    
    # 리뷰 가져오기 
    for i in range(20):
        review_xpath = '//*[@id="section_review"]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '3'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df3 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df3
# Out:
#    Grade                                             Review
# 0      3  여러 공청기 중에서 포름알데히드 제거 성능을 강조한 것 때문에 다이슨을 선택. 마침...
# 1      3  꽃가루때문에 공기청정기 되는것으로 구입했어요\n바람세기 선풍기처럼 와 시원해 느낌은...
# 2      3  이쁜데 소리가 너무 커요\n1에서 10까지 인데 1도 소리가 커요\n이게 고장인지 ...
# 3      3  미세먼지 수치 센서불량으로 사자마자 AS받고 교환진행중. 대여로 임시받은 동일제품도...
# 4      3       외관 흠집, 오염 , 버 절단면 등이 있어\n교환했지만 , 비슷하여 그냥 써요.
# 5      3  공간차지 많이 안하고 디자인은 좋아요! 미세먼지도 잘 잡히네요~ 근데 voc수치는 ...
# 6      3  새집으로 이사가는거라 이사전에 주문해서 비교해봤는데... 별다른 감지가 없네요\n포...
# 7      3                                 소음이 좀 좋아서 그렇지. 조아요
# 8      3  공기청정기에서 소음이 자꾸 나네요\n계속 나는 건 아니고 간헐적으로 들려요\nas를...
# 9      3                         기스가 나있어요 필터끼우는 안쪽이라 그냥 씁니다
# 10     3                              감사합니다 🙏 좋은 제품이길 기대합니다
# 11     3  새집증후군 우려로 구입했는데 평상시 냄새제거나 미세먼지,황사에는 효과가 어떤지 모르...
# 12     3  다좋은데 앱연결이 자주 끊겨서 다시연결해야하는게 넘 불편해요 멀티탭에 연결하면 일주...
# 13     3                  오래 틀어 놓으면 공기가 건조해지긴 하는데 좋긴 하겠죠...
# 14     3                                 시끄러워욤..... 모터소리 ㅠㅠ
# 15     3                                         소음이 꽤 크내요.
# 16     3  배송도 빠른배송입니다\n단 박스에 구멍나서 왔지만\n제품에는 문제 없어서 그냥 사용...
# 17     3               생각보다 팬소음이 커서 좀 놀랐지만. 공기청정기능은 좋기를 기대함
# 18     3                          좋은 가격에 잘 구매했습니다. 배송이 느려요!

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
global url
url = 'https://search.shopping.naver.com/catalog/30242647618?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhnbmbl4%7Cci%3D561716a728d0988abfd7c97771d215090227d58a%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Dbe2a76fbcdf75a9f67fdf1a0cb1b41566709e6e0'
time.sleep(1)

wd.get(url)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[4]/a').click()
time.sleep(1)

#2점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[5]/a').click()
time.sleep(1)

#1페이지
page_xpath = '//*[@id="section_review"]/div[3]/a[1]'

from selenium.common.exceptions import NoSuchElementException

review_data = []

    # 리뷰 가져오기 
for i in range(20):
    review_xpath = '//*[@id="section_review"]/ul/li[{}]/div[2]/div[1]/p'.format(i)
    grade = '2'
    try:
        review_text = wd.find_element(By.XPATH, review_xpath).text
        review_data.append([grade, review_text])
    except NoSuchElementException:
        continue
        
review_df2 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df2
# Out:
#   Grade                                  Review
# 0     2       품질이나 배송은 만족하는데 어플가입이 어렵고 호환도 잘 안됨
# 1     2  달달달 쏴아아 시끄럽습니다 ㅜㅜ바람은 약하고 공기청정은 잘모르겠습니디

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
global url
url = 'https://search.shopping.naver.com/catalog/30242647618?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhnbmbl4%7Cci%3D561716a728d0988abfd7c97771d215090227d58a%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Dbe2a76fbcdf75a9f67fdf1a0cb1b41566709e6e0'
time.sleep(1)

wd.get(url)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[4]/a').click()
time.sleep(1)

#1점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[6]/a').click()
time.sleep(1)

#1페이지
page_xpath = '//*[@id="section_review"]/div[3]/a[1]'

from selenium.common.exceptions import NoSuchElementException

review_data = []

    # 리뷰 가져오기 
for i in range(20):
    review_xpath = '//*[@id="section_review"]/ul/li[{}]/div[2]/div[1]/p'.format(i)
    grade = '1'
    try:
        review_text = wd.find_element(By.XPATH, review_xpath).text
        review_data.append([grade, review_text])
    except NoSuchElementException:
        continue
        
review_df1 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df = pd.concat([review_df1, review_df2, review_df3, review_df4, review_df5], ignore_index=True)
review_df['ItemNm'] = '다이슨 TP09 쿨 포름알데히드 공기청정기'

# %%
# Excel file
review_df.to_excel('다이슨 TP09 쿨 포름알데히드 공기청정기.xlsx', index=False)

# CSV file
review_df.to_csv('다이슨 TP09 쿨 포름알데히드 공기청정기.csv', index=False)
