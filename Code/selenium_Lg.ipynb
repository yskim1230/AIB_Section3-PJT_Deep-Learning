# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from time import sleep
import requests
import re
import pandas as pd
import numpy as np
import os
import time
import warnings
warnings.filterwarnings('ignore')

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

# Mac에서 brew로 설치한 chromedriver의 경로
webdriver_path = '/usr/local/bin/chromedriver'

# mac Chrome (brew로 chromedriver 설치한 경우)
global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
url = 'https://search.shopping.naver.com/catalog/25838038523?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhlp2xug%7Cci%3D6fec79425faba3e7171b46773e66bca7df9d4f16%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3D012d1bff246b42d8d8693aa0f51002a96222e3a8'
time.sleep(1)
wd.get(url)

wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[3]/a').click()
time.sleep(1)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[2]/a').click()
time.sleep(1)

#5점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[2]/a').click()
time.sleep(1)

#1페이지
page_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[1]'

#다음페이지
nextpage_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[11]'

import time
from selenium.common.exceptions import NoSuchElementException

review_data = []

for j in range(1, 11):
    # 페이지 선택
    page_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[{}]'.format(j)
    wd.find_element(By.XPATH, page_xpath).click()
    time.sleep(1)
    
    # 리뷰 가져오기
    for i in range(20):
        review_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '5'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df5 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df5
# Out:
#     Grade                                             Review
# 0       5  깨끗한 디자인과\n\n각 미세먼지, 초미세먼지, 극초미세먼지\n이렇게 세가지 각 먼...
# 1       5  좋은 제품 저렴한 가격에 구매한것에 아주 만족합니다 .\n한달동안 사용하면서 느낀점...
# 2       5  집에서 한 3년 이상 해당 모델의 2층(?) 형을 잘 쓰고 있어서\n황사는 심해지고...
# 3       5  공기청정기 사용 후기 남깁니다💯💯\n기존에 lg 몽블랑 공기청정기로 사용하고 있었는...
# 4       5  첫번째 배송이 진짜 빨라요\n토요일 구매하며 조금 걱정되긴했지만 어버이날 딱 맞추어...
# ..    ...                                                ...
# 185     5  처음사보는 기기인데 좋은거 같아요\n음.., 먼지가 덜쌓이는 느낌? 처음부터 지금까...
# 186     5                           작동 잘되고 생각보다 소음이 없어서 좋아요!
# 187     5                             아주 좋습니다ㅎㅎ 디자인도 성능도 최고ㅋ
# 188     5                              좋아요 잘쓸게요 무빙휠도 편하고 좋네요
# 189     5                               사이즈도 딱 좋고 디자인 맘에 들어요
#
# [190 rows x 2 columns]

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

# Mac에서 brew로 설치한 chromedriver의 경로
webdriver_path = '/usr/local/bin/chromedriver'

# mac Chrome (brew로 chromedriver 설치한 경우)
global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
url = 'https://search.shopping.naver.com/catalog/25838038523?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhlp2xug%7Cci%3D6fec79425faba3e7171b46773e66bca7df9d4f16%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3D012d1bff246b42d8d8693aa0f51002a96222e3a8'
time.sleep(1)
wd.get(url)

wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[3]/a').click()
time.sleep(1)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[2]/a').click()
time.sleep(1)

#4점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[3]/a').click()
time.sleep(1)

#1페이지
page_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[1]'

#다음페이지
nextpage_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[11]'

import time
from selenium.common.exceptions import NoSuchElementException

review_data = []

for j in range(1, 8):
    # 페이지 선택
    page_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[{}]'.format(j)
    wd.find_element(By.XPATH, page_xpath).click()
    time.sleep(1)
    
    # 리뷰 가져오기
    for i in range(20):
        review_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '4'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df4 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df4
# Out:
#     Grade                                             Review
# 0       4  공기청정기 여러 제품비교 고민 하다 믿음이 가는 엘지거로 했어요 이보다 저렴한 제품...
# 1       4  이게 잘 되는건지 조금 애매합니다. 구매하고 얼마 안있어서 고장나서 수리 요청해서 ...
# 2       4  사용한지 며칠 안돼서 성능은 아직 잘 모르겠습니다. 옆에서 요리를 하는데도 계속 청...
# 3       4  빠른배송 좋았습니다 그런데 극초미세먼지와 초미세먼지가 하루에 5-6번정도 나쁨으로 ...
# 4       4  방안이 쾌적해진 것 같아요! 조금 아쉬운건 공간 때문에 구석에 설치해놨는데 pm 센...
# ..    ...                                                ...
# 120     4  공기청정기에 관한 글을 검색해서 이것저것 따져서 선택한 청정기 입니다. 잘 사용하겠...
# 121     4                            사용 전입니다. 기대감에 별4개 드립니다.
# 122     4                                배송이 총알배송이네요 가전윤 엘지~
# 123     4                                     맑은공기, 상쾌한 아침……
# 124     4                                   zzzxxxcccvvvbbb.
#
# [125 rows x 2 columns]

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

# Mac에서 brew로 설치한 chromedriver의 경로
webdriver_path = '/usr/local/bin/chromedriver'

# mac Chrome (brew로 chromedriver 설치한 경우)
global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
url = 'https://search.shopping.naver.com/catalog/25838038523?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhlp2xug%7Cci%3D6fec79425faba3e7171b46773e66bca7df9d4f16%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3D012d1bff246b42d8d8693aa0f51002a96222e3a8'
time.sleep(1)
wd.get(url)

wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[3]/a').click()
time.sleep(1)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[2]/a').click()
time.sleep(1)

#3점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[4]/a').click()
time.sleep(1)

#1페이지
page_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[1]'

#다음페이지
nextpage_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[11]'

import time
from selenium.common.exceptions import NoSuchElementException

review_data = []
    # 리뷰 가져오기
for i in range(20):
        review_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '3'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df3 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df3
# Out:
#    Grade                                             Review
# 0      3  포장상태가 엉망이었어요.\n노끈만 제거했을 뿐인데, 제품이 나오더라구여,\n비닐도 ...
# 1      3  배송도 빠르고, 제품은 브랜드 제품이라 품질은 좋을거라 생각되요.\n다만 아쉬운 점...
# 2      3                상품은 만족하나 배송이 아쉽네요\n배송중 신경을 써야될거 같네요
# 3      3                                     조아요조아요조아요조아요조아
# 4      3                                      조이ㅜ요조아요조아요조아요
# 5      3                       기계 고장인지 오랜시간 동안 미세먼지 있다고 뜨네요
# 6      3  한달 사용하다보니 냄새는 그렇게 싹 가시지 않네요. 오늘도 배추 된장국 끓였는데 나...
# 7      3                  자꾸 중간중간 꺼져서 AS기사님 한번 다녀가셨는데 또 그래요
# 8      3                                      굿굿굿\n굿굿굿\n굿굿굿
# 9      3                              소음이 매우 적어 사용하기 편리합니다.
# 10     3                                    고민많이 했는데 만족스러워요
# 11     3     잘 받앗습니다 택배도착한게 너무 던져놓고간거같아서 기분은 별로였어요 ㅠㅠㅋ 잘쓸게요
# 12     3                           사용잘하고 있어요 그런데 배송이 오래걸리네요
# 13     3                                     위에 먼지가 잘 끼네요 ㅠ
# 14     3                                                 좋음

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable_dev-shm-usage')

# Mac에서 brew로 설치한 chromedriver의 경로
webdriver_path = '/usr/local/bin/chromedriver'

# mac Chrome (brew로 chromedriver 설치한 경우)
global wd
wd = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options) # option넣으면 창 자동으로 안열림
time.sleep(1)
#링크열기
url = 'https://search.shopping.naver.com/catalog/25838038523?query=%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&NaPm=ct%3Dlhlp2xug%7Cci%3D6fec79425faba3e7171b46773e66bca7df9d4f16%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3D012d1bff246b42d8d8693aa0f51002a96222e3a8'
time.sleep(1)
wd.get(url)

wd.find_element(By.XPATH,'//*[@id="snb"]/ul/li[3]/a').click()
time.sleep(1)

#리뷰 클릭
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[2]/a').click()
time.sleep(1)

#1점 선택
wd.find_element(By.XPATH,'//*[@id="section_review"]/div[2]/div[2]/ul/li[6]/a').click()
time.sleep(1)

#1페이지
page_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[1]'

#다음페이지
nextpage_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/div[3]/a[11]'

import time
from selenium.common.exceptions import NoSuchElementException

review_data = []
    # 리뷰 가져오기
for i in range(20):
        review_xpath = '/html/body/div/div/div[2]/div[2]/div[2]/div[3]/div[5]/ul/li[{}]/div[2]/div[1]/p'.format(i)
        grade = '1'
        try:
            review_text = wd.find_element(By.XPATH, review_xpath).text
            review_data.append([grade, review_text])
        except NoSuchElementException:
            continue
        
review_df1 = pd.DataFrame(review_data, columns=['Grade', 'Review'])

# %%
review_df1
# Out:
#   Grade                                             Review
# 0     1  별1개도 아깝습니다. 부모님댁에 선물로 사드린건데 처음 받았을때부터 제대로 동작을 ...
# 1     1  제품마다 차이는 있겠지만 밑바닥 부분 하얗게 사출이 심한편이라니까 속상하네요. 최선...
# 2     1  상품은 늘 쓰던 LG전자의 새 제품이라 역시 만족스럽고, 배송도 잘 해주셨습니다.\...
# 3     1                                       조아요죠아요조아요조아요
# 4     1                       제품하자 as만 3번 기사님이 오셨음 교체까지 두달
# 5     1  아무리 마케팅용 이미지라고 하지만 사진이 제품하고 같은 제대로 된 사진으로 올려야 ...
# 6     1                                      응대 서비스가 별로였어요
# 7     1                                    설치해준다고하고 문앞에두고감
# 8     1                                       이유없이 환불되었습니다

# %%
review_df = pd.concat([review_df1, review_df3, review_df4, review_df5], ignore_index=True)
review_df['ItemNm'] = 'LG전자 LG퓨리케어 AS171DWFC'

# %%
# Excel file
review_df.to_excel('LG전자 LG퓨리케어 AS171DWFC.xlsx', index=False)

# CSV file
review_df.to_csv('LG전자 LG퓨리케어 AS171DWFC.csv', index=False)
